# %% [markdown]
# <a href="https://colab.research.google.com/github/GertkingABP/Sii_labs/blob/main/sii_L4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from google.colab import files
uploader = files.upload()
# Out:
#      <input type="file" id="files-c7b9754b-070a-4acc-a2fe-a4d4fe05e56f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c7b9754b-070a-4acc-a2fe-a4d4fe05e56f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Marvel Movies.csv")
df.head(15)
# Out:
#                                    name                ID               ALIGN  \
# 0             Spider-Man (Peter Parker)   Secret Identity     Good Characters
# 1       Captain America (Steven Rogers)   Public Identity     Good Characters
# 2   Wolverine (James \"Logan\" Howlett)   Public Identity  Neutral Characters
# 3     Iron Man (Anthony \"Tony\" Stark)   Public Identity     Good Characters
# 4                   Thor (Thor Odinson)  No Dual Identity     Good Characters
# 5            Benjamin Grimm (Earth-616)   Public Identity     Good Characters
# 6             Reed Richards (Earth-616)   Public Identity     Good Characters
# 7            Hulk (Robert Bruce Banner)   Public Identity     Good Characters
# 8             Scott Summers (Earth-616)   Public Identity  Neutral Characters
# 9            Jonathan Storm (Earth-616)   Public Identity     Good Characters
# 10              Henry McCoy (Earth-616)   Public Identity     Good Characters
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16376 entries, 0 to 16375
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              16376 non-null  object
#  1   ID                12606 non-null  object
#  2   ALIGN             13564 non-null  object
#  3   EYE               6609 non-null   object
#  4   HAIR              12112 non-null  object
#  5   SEX               15522 non-null  object
#  6   GSM               90 non-null     object
#  7   ALIVE             16373 non-null  object
#  8   APPEARANCES       15280 non-null  float64
#  9   FIRST APPEARANCE  15561 non-null  object
#  10  Year              15561 non-null  float64
# dtypes: float64(2), object(9)
# memory usage: 1.4+ MB

# %%
df.nunique()
# Out:
# name                16376
# ID                      4
# ALIGN                   3
# EYE                    24
# HAIR                   25
# SEX                     4
# GSM                     6
# ALIVE                   2
# APPEARANCES           358
# FIRST APPEARANCE      832
# Year                   75
# dtype: int64

# %%
col_name = ['name', 'ID', 'ALIGN', 'EYE', 'HAIR', 'SEX', 'GSM', 'ALIVE', 'APPEARANCES', 'FIRST APPEARANCE', 'Year']
df.set_axis(col_name, axis = 'columns')
# Out:
#                                       name                ID  \
# 0                Spider-Man (Peter Parker)   Secret Identity
# 1          Captain America (Steven Rogers)   Public Identity
# 2      Wolverine (James \"Logan\" Howlett)   Public Identity
# 3        Iron Man (Anthony \"Tony\" Stark)   Public Identity
# 4                      Thor (Thor Odinson)  No Dual Identity
# ...                                    ...               ...
# 16371                   Ru'ach (Earth-616)  No Dual Identity
# 16372      Thane (Thanos' son) (Earth-616)  No Dual Identity
# 16373        Tinkerer (Skrull) (Earth-616)   Secret Identity
# 16374       TK421 (Spiderling) (Earth-616)   Secret Identity
# 16375                Yologarch (Earth-616)               NaN
#
#                     ALIGN         EYE        HAIR              SEX  GSM  \
# 0         Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1         Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# ...

# %%
df.dropna(subset = ['Year'], inplace=True)
df.Year.unique()
df.Year = df.Year.replace('None', np.nan)

# %%
df.Year.unique()
# Out:
# array([1962., 1941., 1974., 1963., 1950., 1961., 1975., 1964., 1965.,
#        1968., 1980., 1972., 1970., 1967., 1976., 1966., 1982., 1990.,
#        1986., 1969., 1944., 1939., 1949., 1979., 1991., 1977., 1989.,
#        1940., 1978., 1971., 1984., 2005., 1973., 1945., 1985., 1992.,
#        1988., 1948., 1981., 2004., 1983., 2000., 2003., 1960., 1987.,
#        1951., 1994., 2008., 2006., 2001., 2002., 1993., 1953., 1943.,
#        1995., 1947., 1956., 2010., 1946., 1998., 2009., 1997., 1996.,
#        2011., 1954., 2012., 1999., 1955., 2007., 2013., 1952., 1942.,
#        1958., 1957., 1959.])

# %%
df[df['APPEARANCES'].isnull() == True]
# Out:
#                                                     name                ID  \
# 15280               Minister of Castile D'or (Earth-616)  No Dual Identity
# 15281                  Mr. Harris' Secretary (Earth-616)  No Dual Identity
# 15282                                 N'Jaga (Earth-616)  No Dual Identity
# 15283                                  Ertve (Earth-616)   Secret Identity
# 15284                   Invisible Man (Gade) (Earth-616)   Secret Identity
# ...                                                  ...               ...
# 16171  \"Spider-Girl\" (Mutant\/Spider Clone) (Earth-...  No Dual Identity
# 16172                           James Monroe (Earth-616)   Public Identity
# 16173                  Katy & Timothy Bashir (Earth-616)   Secret Identity
# 16174                            Mister Z'zz (Earth-616)               NaN
# 16175                           Mole Monster (Earth-616)   Secret Identity
#
# ...

# %%
df[df.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [name, ID, ALIGN, EYE, HAIR, SEX, GSM, ALIVE, APPEARANCES, FIRST APPEARANCE, Year]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15561 entries, 0 to 16175
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              15561 non-null  object
#  1   ID                11959 non-null  object
#  2   ALIGN             12889 non-null  object
#  3   EYE               6212 non-null   object
#  4   HAIR              11558 non-null  object
#  5   SEX               14766 non-null  object
#  6   GSM               85 non-null     object
#  7   ALIVE             15561 non-null  object
#  8   APPEARANCES       14665 non-null  float64
#  9   FIRST APPEARANCE  15561 non-null  object
#  10  Year              15561 non-null  float64
# dtypes: float64(2), object(9)
# memory usage: 1.4+ MB
